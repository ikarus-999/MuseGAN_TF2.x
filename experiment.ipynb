# %%
import os
import numpy as np
from pathlib import Path
from music21 import *

from tqdm import tqdm
import pypianoroll
from pypianoroll import Track, Multitrack, BinaryTrack, StandardTrack

# %%
# Data
n_tracks = 5  # number of tracks
n_pitches = 84  # number of pitches
lowest_pitch = 24  # MIDI note number of the lowest pitch
n_samples_per_song = 4  # number of samples to extract from each song in the datset
n_measures = 4  # number of measures per sample
beat_resolution = 4  # temporal resolution of a beat (in timestep)
programs = [0, 0, 25, 33, 48]  # program number for each track
is_drums = [True, False, False, False, False]  # drum indicator for each track
track_names = ['Drums', 'Piano', 'Guitar', 'Bass', 'Strings']  # name of each track
tempo = 120

# %%
measure_resolution = 4 * beat_resolution
tempo_array = np.full((4 * 4 * measure_resolution, 1), tempo)
assert 24 % beat_resolution == 0, (
    "beat_resolution must be a factor of 24 (the beat resolution used in "
    "the source dataset)."
)
assert len(programs) == len(is_drums) and len(programs) == len(track_names), (
    "Lengths of programs, is_drums and track_names must be the same."
)

# %%
# !mkdir -p data

# !gdown -O data/lpd_5_cleansed.tar.gz https://drive.google.com/uc?id=1yz0Ma-6cWTl6mhkrLnAVJ7RNzlQRypQ5
# !gdown -O data/id_lists_amg.tar.gz https://drive.google.com/uc?id=1hp9b_g1hu_dkP4u8h46iqHeWMaUoI07R
# !gdown -O data/id_lists_lastfm.tar.gz https://drive.google.com/uc?id=1mpsoxU2fU1AjKopkcQ8Q8V6wYmVPbnPO

# !tar zxf data/lpd_5_cleansed.tar.gz -C data/
# !tar zxf data/id_lists_amg.tar.gz -C data/
# !tar zxf data/id_lists_lastfm.tar.gz -C data/
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1yz0Ma-6cWTl6mhkrLnAVJ7RNzlQRypQ5
# To: /workspace/MuseGAN/data/lpd_5_cleansed.tar.gz
# 100%|████████████████████████████████████████| 555M/555M [00:19<00:00, 28.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1hp9b_g1hu_dkP4u8h46iqHeWMaUoI07R
# To: /workspace/MuseGAN/data/id_lists_amg.tar.gz
# 100%|███████████████████████████████████████| 63.9k/63.9k [00:00<00:00, 959kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1mpsoxU2fU1AjKopkcQ8Q8V6wYmVPbnPO
# To: /workspace/MuseGAN/data/id_lists_lastfm.tar.gz
# 100%|████████████████████████████████████████| 668k/668k [00:00<00:00, 3.02MB/s]

# %%
dataset_root = Path("data/lpd_5/lpd_5_cleansed/")

id_list = []
for path in os.listdir("data/amg"):
    filepath = os.path.join("data/amg", path)
    # print(path)
    
    if os.path.isfile(filepath):
        with open(filepath) as f:
            id_list.extend([line.rstrip() for line in f])
id_list = list(set(id_list))

# %%
def msd_id_to_dirs(msd_id):
    """Given an MSD ID, generate the path prefix.
    E.g. TRABCD12345678 -> A/B/C/TRABCD12345678"""
    return os.path.join(msd_id[2], msd_id[3], msd_id[4], msd_id)

# %%
data = []
max_num = 500 
file_idx = 0
bar_num = 4

for msd_id in tqdm(id_list):
    song_dir = dataset_root / msd_id_to_dirs(msd_id)
    multitrack = pypianoroll.load(song_dir / os.listdir(song_dir)[0])
    
    # (shape: n_timesteps x n_pitches)
    multitrack.set_resolution(beat_resolution)
    # Stack the pianoroll (shape: n_tracks x n_timesteps x n_pitches)
    pianoroll = multitrack.stack()
    
    pianoroll = pianoroll[:, :, lowest_pitch:lowest_pitch + n_pitches]
    
    # pianoroll = np.pad(pianoroll, ((0, 0), (0,0), (lowest_pitch, 128 - lowest_pitch - n_pitches)))
    n_total_measures = multitrack.get_max_length() // measure_resolution
    candidate = n_total_measures - n_measures
    target_n_samples = min(n_total_measures // n_measures, n_samples_per_song)
    
    for idx in range(candidate):
        start = idx * measure_resolution
        end = (idx + n_measures * 6) * measure_resolution
        
        if (pianoroll.sum(axis=(1, 2)) < 10).any() or pianoroll[:, start:end].shape[1] < 384: # 96*4
            continue
        
        #tracks = []
        #for trk, (program, is_drum, track_name) in enumerate(zip(programs, is_drums, track_names)):
        #    tracks.append(StandardTrack(name=track_name, program=program, is_drum=is_drum, pianoroll=(pianoroll[trk, start:end] > 0.5)))
        #multi = Multitrack(tracks=tracks, tempo=tempo_array, resolution=beat_resolution)
        # print(pianoroll[:, start:end].shape)

        # print(pianoroll[:, start:end].reshape(n_tracks, 4, -1, n_pitches).shape)
        
        data.append(pianoroll[:, start:end].reshape(n_tracks, bar_num, -1, n_pitches)) # reshape 48 * 16
        #multi.write(f'./temp_midi_data/dataset_{file_idx}.mid')
    file_idx += 1
    if file_idx > max_num-1:
        print(file_idx)
        break

data = np.stack(data)
print(f"Successfully collect {len(data)} samples from {len(id_list)} songs")
print(f"Data shape : {data.shape}")
dataset = data.transpose(0, 2, 3, 4, 1)
print(f'finally dataset {dataset.shape}')
# Out:
#   7%|▋         | 499/7323 [01:16<17:28,  6.51it/s]
# 500
# Successfully collect 18000 samples from 7323 songs
# Data shape : (18000, 5, 4, 96, 84)
# finally dataset (18000, 4, 96, 84, 5)

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from museGAN2 import MuseGAN
# Out:
# 2021-10-23 13:31:01.325960: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
dataset.shape
# Out:
# (18000, 4, 96, 84, 5)

# %%
dataset_1 = dataset[:, :3, :32, :, :]

# %%
dataset_1.shape
# Out:
# (18000, 3, 32, 84, 5)

# %%
# run params
SECTION = 'compose'
RUN_ID = '005'
DATA_NAME = 'lpd_5'
RUN_FOLDER = f'run/{SECTION}/'
RUN_FOLDER += '_'.join([RUN_ID, DATA_NAME])

if not os.path.exists(RUN_FOLDER):
    os.makedirs(RUN_FOLDER)
    os.makedirs(os.path.join(RUN_FOLDER, 'viz'))
    os.makedirs(os.path.join(RUN_FOLDER, 'images'))
    os.makedirs(os.path.join(RUN_FOLDER, 'weights'))
    os.makedirs(os.path.join(RUN_FOLDER, 'samples'))
    os.makedirs(os.path.join(RUN_FOLDER, 'dataset'))

mode =  'build' # ' 'load' #

# %%
BATCH_SIZE = 64
n_bars = 3
n_steps_per_bar = 32
n_pitches = 84
n_tracks = 5

# %%
gan = MuseGAN(input_dim = (3, 32, 84, 5)
        , critic_learning_rate = 0.001
        , generator_learning_rate = 0.001
        , optimiser = 'adam'
        , grad_weight = 10
        , z_dim = 32
        , batch_size = BATCH_SIZE
        , n_tracks = n_tracks
        , n_bars = n_bars
        , n_steps_per_bar = n_steps_per_bar
        , n_pitches = n_pitches
        )

if mode == 'build':
    gan.save(RUN_FOLDER)
else:                 
    gan.load_weights(RUN_FOLDER)
# Out:
# 2021-10-23 13:31:47.300089: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-10-23 13:31:47.301517: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-10-23 13:31:47.351721: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-23 13:31:47.352964: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:05.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.72GiB deviceMemoryBandwidth: 836.37GiB/s
# 2021-10-23 13:31:47.353074: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-23 13:31:47.354305: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:00:06.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.72GiB deviceMemoryBandwidth: 836.37GiB/s
# 2021-10-23 13:31:47.354364: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-10-23 13:31:47.356281: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-10-23 13:31:47.356382: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-10-23 13:31:47.358153: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-10-23 13:31:47.358519: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-10-23 13:31:47.360369: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-10-23 13:31:47.361246: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-10-23 13:31:47.365349: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-10-23 13:31:47.365519: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-23 13:31:47.366838: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-23 13:31:47.368087: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-23 13:31:47.369309: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-23 13:31:47.370499: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2021-10-23 13:31:52.645821: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-23 13:31:52.815352: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-23 13:31:52.816710: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:05.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.72GiB deviceMemoryBandwidth: 836.37GiB/s
# 2021-10-23 13:31:52.816947: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-23 13:31:52.818225: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:00:06.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.72GiB deviceMemoryBandwidth: 836.37GiB/s
# 2021-10-23 13:31:52.818319: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-10-23 13:31:52.818376: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-10-23 13:31:52.818406: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-10-23 13:31:52.818430: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-10-23 13:31:52.818455: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-10-23 13:31:52.818483: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-10-23 13:31:52.818505: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-10-23 13:31:52.818527: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-10-23 13:31:52.818649: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-23 13:31:52.820022: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-23 13:31:52.821352: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-23 13:31:52.822693: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-23 13:31:52.823927: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2021-10-23 13:31:52.824084: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-10-23 13:31:54.643758: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-10-23 13:31:54.643804: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0 1
# 2021-10-23 13:31:54.643812: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N Y
# 2021-10-23 13:31:54.643815: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 1:   Y N
# 2021-10-23 13:31:54.644255: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-23 13:31:54.645566: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-23 13:31:54.646881: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-23 13:31:54.648125: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-23 13:31:54.649317: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30095 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:00:05.0, compute capability: 7.0)
# 2021-10-23 13:31:54.649841: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-23 13:31:54.651146: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-23 13:31:54.652325: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 30095 MB memory) -> physical GPU (device: 1, name: Tesla V100-SXM2-32GB, pci bus id: 0000:00:06.0, compute capability: 7.0)
# 2021-10-23 13:31:54.652599: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-10-23 13:31:54.899576: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:196] None of the MLIR optimization passes are enabled (registered 0 passes)
# 2021-10-23 13:31:55.216576: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2200100000 Hz
# gen_output: (None, 3, 32, 84, 5)
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
gan.chords_tempNetwork.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# temporal_input (InputLayer)  [(None, 32)]              0
# _________________________________________________________________
# reshape (Reshape)            (None, 1, 1, 32)          0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 2, 1, 1024)        66560
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 2, 1, 1024)        4096
# _________________________________________________________________
# activation (Activation)      (None, 2, 1, 1024)        0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 3, 1, 32)          65568
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 3, 1, 32)          128
# _________________________________________________________________
# activation_1 (Activation)    (None, 3, 1, 32)          0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 3, 32)             0
# =================================================================
# Total params: 136,352
# Trainable params: 134,240
# Non-trainable params: 2,112
# _________________________________________________________________

# %%
gan.generator.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# melody_input (InputLayer)       [(None, 5, 32)]      0
# __________________________________________________________________________________________________
# chords_input (InputLayer)       [(None, 32)]         0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 32)           0           melody_input[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 32)           0           melody_input[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 32)           0           melody_input[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 32)           0           melody_input[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 32)           0           melody_input[0][0]
# __________________________________________________________________________________________________
# model_1 (Functional)            (None, 3, 32)        136352      chords_input[0][0]
# __________________________________________________________________________________________________
# model_2 (Functional)            (None, 3, 32)        136352      lambda[0][0]
# __________________________________________________________________________________________________
# groove_input (InputLayer)       [(None, 5, 32)]      0
# __________________________________________________________________________________________________
# model_3 (Functional)            (None, 3, 32)        136352      lambda_1[0][0]
# __________________________________________________________________________________________________
# model_4 (Functional)            (None, 3, 32)        136352      lambda_2[0][0]
# __________________________________________________________________________________________________
# model_5 (Functional)            (None, 3, 32)        136352      lambda_3[0][0]
# __________________________________________________________________________________________________
# model_6 (Functional)            (None, 3, 32)        136352      lambda_4[0][0]
# __________________________________________________________________________________________________
# chords_input_bar_0 (Lambda)     (None, 32)           0           model_1[0][0]
# __________________________________________________________________________________________________
# style_input (InputLayer)        [(None, 32)]         0
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 32)           0           model_2[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 32)           0           groove_input[0][0]
# __________________________________________________________________________________________________
# condition_input (InputLayer)    [(None, 96, 84, 1)]  0
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 32)           0           model_3[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 32)           0           groove_input[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 32)           0           model_4[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 32)           0           groove_input[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 32)           0           model_5[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 32)           0           groove_input[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 32)           0           model_6[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 32)           0           groove_input[0][0]
# __________________________________________________________________________________________________
# chords_input_bar_1 (Lambda)     (None, 32)           0           model_1[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 32)           0           model_2[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 32)           0           groove_input[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 32)           0           model_3[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 32)           0           groove_input[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 32)           0           model_4[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 32)           0           groove_input[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 32)           0           model_5[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 32)           0           groove_input[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 32)           0           model_6[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 32)           0           groove_input[0][0]
# __________________________________________________________________________________________________
# chords_input_bar_2 (Lambda)     (None, 32)           0           model_1[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 32)           0           model_2[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 32)           0           groove_input[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 32)           0           model_3[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 32)           0           groove_input[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 32)           0           model_4[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 32)           0           groove_input[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 32)           0           model_5[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 32)           0           groove_input[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, 32)           0           model_6[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 32)           0           groove_input[0][0]
# __________________________________________________________________________________________________
# total_input_bar_0_track_0 (Conc (None, 128)          0           chords_input_bar_0[0][0]
#                                                                  style_input[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
# __________________________________________________________________________________________________
# bar_encoder (BarEncoder)        [(None, 96, 7, 16),  0           condition_input[0][0]
# __________________________________________________________________________________________________
# total_input_bar_0_track_1 (Conc (None, 128)          0           chords_input_bar_0[0][0]
#                                                                  style_input[0][0]
#                                                                  lambda_7[0][0]
#                                                                  lambda_8[0][0]
# __________________________________________________________________________________________________
# total_input_bar_0_track_2 (Conc (None, 128)          0           chords_input_bar_0[0][0]
#                                                                  style_input[0][0]
#                                                                  lambda_9[0][0]
#                                                                  lambda_10[0][0]
# __________________________________________________________________________________________________
# total_input_bar_0_track_3 (Conc (None, 128)          0           chords_input_bar_0[0][0]
#                                                                  style_input[0][0]
#                                                                  lambda_11[0][0]
#                                                                  lambda_12[0][0]
# __________________________________________________________________________________________________
# total_input_bar_0_track_4 (Conc (None, 128)          0           chords_input_bar_0[0][0]
#                                                                  style_input[0][0]
#                                                                  lambda_13[0][0]
#                                                                  lambda_14[0][0]
# __________________________________________________________________________________________________
# total_input_bar_1_track_0 (Conc (None, 128)          0           chords_input_bar_1[0][0]
#                                                                  style_input[0][0]
#                                                                  lambda_15[0][0]
#                                                                  lambda_16[0][0]
# __________________________________________________________________________________________________
# total_input_bar_1_track_1 (Conc (None, 128)          0           chords_input_bar_1[0][0]
#                                                                  style_input[0][0]
#                                                                  lambda_17[0][0]
#                                                                  lambda_18[0][0]
# __________________________________________________________________________________________________
# total_input_bar_1_track_2 (Conc (None, 128)          0           chords_input_bar_1[0][0]
#                                                                  style_input[0][0]
#                                                                  lambda_19[0][0]
#                                                                  lambda_20[0][0]
# __________________________________________________________________________________________________
# total_input_bar_1_track_3 (Conc (None, 128)          0           chords_input_bar_1[0][0]
#                                                                  style_input[0][0]
#                                                                  lambda_21[0][0]
#                                                                  lambda_22[0][0]
# __________________________________________________________________________________________________
# total_input_bar_1_track_4 (Conc (None, 128)          0           chords_input_bar_1[0][0]
#                                                                  style_input[0][0]
#                                                                  lambda_23[0][0]
#                                                                  lambda_24[0][0]
# __________________________________________________________________________________________________
# total_input_bar_2_track_0 (Conc (None, 128)          0           chords_input_bar_2[0][0]
#                                                                  style_input[0][0]
#                                                                  lambda_25[0][0]
#                                                                  lambda_26[0][0]
# __________________________________________________________________________________________________
# total_input_bar_2_track_1 (Conc (None, 128)          0           chords_input_bar_2[0][0]
#                                                                  style_input[0][0]
#                                                                  lambda_27[0][0]
#                                                                  lambda_28[0][0]
# __________________________________________________________________________________________________
# total_input_bar_2_track_2 (Conc (None, 128)          0           chords_input_bar_2[0][0]
#                                                                  style_input[0][0]
#                                                                  lambda_29[0][0]
#                                                                  lambda_30[0][0]
# __________________________________________________________________________________________________
# total_input_bar_2_track_3 (Conc (None, 128)          0           chords_input_bar_2[0][0]
#                                                                  style_input[0][0]
#                                                                  lambda_31[0][0]
#                                                                  lambda_32[0][0]
# __________________________________________________________________________________________________
# total_input_bar_2_track_4 (Conc (None, 128)          0           chords_input_bar_2[0][0]
#                                                                  style_input[0][0]
#                                                                  lambda_33[0][0]
#                                                                  lambda_34[0][0]
# __________________________________________________________________________________________________
# bar_generator (BarGenerator)    (None, 96, 84, 1)    0           total_input_bar_0_track_0[0][0]
#                                                                  bar_encoder[0][0]
#                                                                  bar_encoder[0][1]
#                                                                  bar_encoder[0][2]
#                                                                  bar_encoder[0][3]
#                                                                  bar_encoder[0][4]
#                                                                  bar_encoder[0][5]
#                                                                  bar_encoder[0][6]
#                                                                  total_input_bar_1_track_0[0][0]
#                                                                  bar_encoder[0][0]
#                                                                  bar_encoder[0][1]
#                                                                  bar_encoder[0][2]
#                                                                  bar_encoder[0][3]
#                                                                  bar_encoder[0][4]
#                                                                  bar_encoder[0][5]
#                                                                  bar_encoder[0][6]
#                                                                  total_input_bar_2_track_0[0][0]
#                                                                  bar_encoder[0][0]
#                                                                  bar_encoder[0][1]
#                                                                  bar_encoder[0][2]
#                                                                  bar_encoder[0][3]
#                                                                  bar_encoder[0][4]
#                                                                  bar_encoder[0][5]
#                                                                  bar_encoder[0][6]
# __________________________________________________________________________________________________
# bar_generator_1 (BarGenerator)  (None, 96, 84, 1)    0           total_input_bar_0_track_1[0][0]
#                                                                  bar_encoder[0][0]
#                                                                  bar_encoder[0][1]
#                                                                  bar_encoder[0][2]
#                                                                  bar_encoder[0][3]
#                                                                  bar_encoder[0][4]
#                                                                  bar_encoder[0][5]
#                                                                  bar_encoder[0][6]
#                                                                  total_input_bar_1_track_1[0][0]
#                                                                  bar_encoder[0][0]
#                                                                  bar_encoder[0][1]
#                                                                  bar_encoder[0][2]
#                                                                  bar_encoder[0][3]
#                                                                  bar_encoder[0][4]
#                                                                  bar_encoder[0][5]
#                                                                  bar_encoder[0][6]
#                                                                  total_input_bar_2_track_1[0][0]
#                                                                  bar_encoder[0][0]
#                                                                  bar_encoder[0][1]
#                                                                  bar_encoder[0][2]
#                                                                  bar_encoder[0][3]
#                                                                  bar_encoder[0][4]
#                                                                  bar_encoder[0][5]
#                                                                  bar_encoder[0][6]
# __________________________________________________________________________________________________
# bar_generator_2 (BarGenerator)  (None, 96, 84, 1)    0           total_input_bar_0_track_2[0][0]
#                                                                  bar_encoder[0][0]
#                                                                  bar_encoder[0][1]
#                                                                  bar_encoder[0][2]
#                                                                  bar_encoder[0][3]
#                                                                  bar_encoder[0][4]
#                                                                  bar_encoder[0][5]
#                                                                  bar_encoder[0][6]
#                                                                  total_input_bar_1_track_2[0][0]
#                                                                  bar_encoder[0][0]
#                                                                  bar_encoder[0][1]
#                                                                  bar_encoder[0][2]
#                                                                  bar_encoder[0][3]
#                                                                  bar_encoder[0][4]
#                                                                  bar_encoder[0][5]
#                                                                  bar_encoder[0][6]
#                                                                  total_input_bar_2_track_2[0][0]
#                                                                  bar_encoder[0][0]
#                                                                  bar_encoder[0][1]
#                                                                  bar_encoder[0][2]
#                                                                  bar_encoder[0][3]
#                                                                  bar_encoder[0][4]
#                                                                  bar_encoder[0][5]
#                                                                  bar_encoder[0][6]
# __________________________________________________________________________________________________
# bar_generator_3 (BarGenerator)  (None, 96, 84, 1)    0           total_input_bar_0_track_3[0][0]
#                                                                  bar_encoder[0][0]
#                                                                  bar_encoder[0][1]
#                                                                  bar_encoder[0][2]
#                                                                  bar_encoder[0][3]
#                                                                  bar_encoder[0][4]
#                                                                  bar_encoder[0][5]
#                                                                  bar_encoder[0][6]
#                                                                  total_input_bar_1_track_3[0][0]
#                                                                  bar_encoder[0][0]
#                                                                  bar_encoder[0][1]
#                                                                  bar_encoder[0][2]
#                                                                  bar_encoder[0][3]
#                                                                  bar_encoder[0][4]
#                                                                  bar_encoder[0][5]
#                                                                  bar_encoder[0][6]
#                                                                  total_input_bar_2_track_3[0][0]
#                                                                  bar_encoder[0][0]
#                                                                  bar_encoder[0][1]
#                                                                  bar_encoder[0][2]
#                                                                  bar_encoder[0][3]
#                                                                  bar_encoder[0][4]
#                                                                  bar_encoder[0][5]
#                                                                  bar_encoder[0][6]
# __________________________________________________________________________________________________
# bar_generator_4 (BarGenerator)  (None, 96, 84, 1)    0           total_input_bar_0_track_4[0][0]
#                                                                  bar_encoder[0][0]
#                                                                  bar_encoder[0][1]
#                                                                  bar_encoder[0][2]
#                                                                  bar_encoder[0][3]
#                                                                  bar_encoder[0][4]
#                                                                  bar_encoder[0][5]
#                                                                  bar_encoder[0][6]
#                                                                  total_input_bar_1_track_4[0][0]
#                                                                  bar_encoder[0][0]
#                                                                  bar_encoder[0][1]
#                                                                  bar_encoder[0][2]
#                                                                  bar_encoder[0][3]
#                                                                  bar_encoder[0][4]
#                                                                  bar_encoder[0][5]
#                                                                  bar_encoder[0][6]
#                                                                  total_input_bar_2_track_4[0][0]
#                                                                  bar_encoder[0][0]
#                                                                  bar_encoder[0][1]
#                                                                  bar_encoder[0][2]
#                                                                  bar_encoder[0][3]
#                                                                  bar_encoder[0][4]
#                                                                  bar_encoder[0][5]
#                                                                  bar_encoder[0][6]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_12 (TensorF multiple             0           bar_generator[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_13 (TensorF multiple             0           bar_generator_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_14 (TensorF multiple             0           bar_generator_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_15 (TensorF multiple             0           bar_generator_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_16 (TensorF multiple             0           bar_generator_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_17 (TensorF multiple             0           bar_generator[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_18 (TensorF multiple             0           bar_generator_1[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_19 (TensorF multiple             0           bar_generator_2[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_20 (TensorF multiple             0           bar_generator_3[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_21 (TensorF multiple             0           bar_generator_4[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_22 (TensorF multiple             0           bar_generator[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_23 (TensorF multiple             0           bar_generator_1[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_24 (TensorF multiple             0           bar_generator_2[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_25 (TensorF multiple             0           bar_generator_3[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_26 (TensorF multiple             0           bar_generator_4[2][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 1, 32, 84, 5) 0           tf_op_layer_Reshape_12[0][0]
#                                                                  tf_op_layer_Reshape_13[0][0]
#                                                                  tf_op_layer_Reshape_14[0][0]
#                                                                  tf_op_layer_Reshape_15[0][0]
#                                                                  tf_op_layer_Reshape_16[0][0]
# __________________________________________________________________________________________________
# concatenate_71 (Concatenate)    (None, 1, 32, 84, 5) 0           tf_op_layer_Reshape_17[0][0]
#                                                                  tf_op_layer_Reshape_18[0][0]
#                                                                  tf_op_layer_Reshape_19[0][0]
#                                                                  tf_op_layer_Reshape_20[0][0]
#                                                                  tf_op_layer_Reshape_21[0][0]
# __________________________________________________________________________________________________
# concatenate_107 (Concatenate)   (None, 1, 32, 84, 5) 0           tf_op_layer_Reshape_22[0][0]
#                                                                  tf_op_layer_Reshape_23[0][0]
#                                                                  tf_op_layer_Reshape_24[0][0]
#                                                                  tf_op_layer_Reshape_25[0][0]
#                                                                  tf_op_layer_Reshape_26[0][0]
# __________________________________________________________________________________________________
# concat_bars (Concatenate)       (None, 3, 32, 84, 5) 0           concatenate_35[0][0]
#                                                                  concatenate_71[0][0]
#                                                                  concatenate_107[0][0]
# ==================================================================================================
# Total params: 818,112
# Trainable params: 805,440
# Non-trainable params: 12,672
# __________________________________________________________________________________________________

# %%
gan.critic.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# critic_input (InputLayer)    [(None, 3, 32, 84, 5)]    0
# _________________________________________________________________
# conv3d (Conv3D)              multiple                  1408
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      multiple                  0
# _________________________________________________________________
# conv3d_1 (Conv3D)            multiple                  32896
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    multiple                  0
# _________________________________________________________________
# conv3d_2 (Conv3D)            multiple                  196736
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    multiple                  0
# _________________________________________________________________
# conv3d_3 (Conv3D)            multiple                  114816
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    multiple                  0
# _________________________________________________________________
# conv3d_4 (Conv3D)            multiple                  32896
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    multiple                  0
# _________________________________________________________________
# conv3d_5 (Conv3D)            multiple                  32896
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    multiple                  0
# _________________________________________________________________
# conv3d_6 (Conv3D)            multiple                  131328
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    multiple                  0
# _________________________________________________________________
# conv3d_7 (Conv3D)            multiple                  393728
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    multiple                  0
# _________________________________________________________________
# flatten (Flatten)            multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  1049600
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    multiple                  0
# _________________________________________________________________
# dense_1 (Dense)              multiple                  1025
# =================================================================
# Total params: 1,987,329
# Trainable params: 1,987,329
# Non-trainable params: 0
# _________________________________________________________________

# %%
dataset_1.shape
# Out:
# (18000, 3, 32, 84, 5)

# %%
gan.critic_model.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# chords_input (InputLayer)       [(None, 32)]         0
# __________________________________________________________________________________________________
# style_input (InputLayer)        [(None, 32)]         0
# __________________________________________________________________________________________________
# melody_input (InputLayer)       [(None, 5, 32)]      0
# __________________________________________________________________________________________________
# groove_input (InputLayer)       [(None, 5, 32)]      0
# __________________________________________________________________________________________________
# condition_input (InputLayer)    [(None, 96, 84, 1)]  0
# __________________________________________________________________________________________________
# real_img_input (InputLayer)     [(None, 3, 32, 84, 5 0
# __________________________________________________________________________________________________
# model_7 (Functional)            (None, 3, 32, 84, 5) 818112      chords_input[0][0]
#                                                                  style_input[0][0]
#                                                                  melody_input[0][0]
#                                                                  groove_input[0][0]
#                                                                  condition_input[0][0]
# __________________________________________________________________________________________________
# random_weighted_average (Random (64, 3, 32, 84, 5)   0           real_img_input[0][0]
#                                                                  model_7[0][0]
# __________________________________________________________________________________________________
# model (Functional)              (None, 1)            1987329     model_7[0][0]
#                                                                  real_img_input[0][0]
#                                                                  random_weighted_average[0][0]
# ==================================================================================================
# Total params: 2,000,001
# Trainable params: 1,987,329
# Non-trainable params: 12,672
# __________________________________________________________________________________________________

# %%
EPOCHS = 4000
PRINT_EVERY_N_BATCHES = 10
gan.epoch = 0

# %%
gan.train(dataset_1, batch_size=BATCH_SIZE, epochs=EPOCHS, run_folder=RUN_FOLDER, print_every_n_batches=PRINT_EVERY_N_BATCHES)
# Out:
# randAvgLayer: []
# randAvgLayer input: [<tf.Tensor 'real_img_input:0' shape=(None, 3, 32, 84, 5) dtype=float32>, <tf.Tensor 'model_7/concat_bars/concat:0' shape=(None, 3, 32, 84, 5) dtype=float32>]
# randAvgLayer output: Tensor("random_weighted_average/add:0", shape=(64, 3, 32, 84, 5), dtype=float32)
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# 2021-10-23 13:38:23.938873: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-10-23 13:38:24.326515: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-10-23 13:38:26.520300: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 2021-10-23 13:38:26.721804: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /tmp/ipykernel_5216/1092802282.py in <module>
# ----> 1 gan.train(dataset_1, batch_size=BATCH_SIZE, epochs=EPOCHS, run_folder=RUN_FOLDER, print_every_n_batches=PRINT_EVERY_N_BATCHES)
#
# /workspace/MuseGAN/museGAN2.py in train(self, x_train, batch_size, epochs, run_folder, print_every_n_batches, n_critic, using_generator)
#     434
#     435             for _ in range(critic_loops):
# --> 436                 d_loss = self.train_critic(x_train, batch_size, using_generator)
#     437
#     438             g_loss = self.train_generator(x_train, batch_size)
#
# /workspace/MuseGAN/museGAN2.py in train_critic(self, x_train, batch_size, using_generator)
#     391         print(f'randAvgLayer output: {self.critic_model.layers[-2].output}')
#     392
# --> 393         d_loss = self.critic_model.train_on_batch([true_imgs, chords_noise, style_noise,melody_noise,groove_noise, acc_track], [valid, fake, dummy])
#     394         return d_loss
#     395
#
# /opt/conda/envs/trial_env_01/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_v1.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1086       self._update_sample_weight_modes(sample_weights=sample_weights)
#    1087       self._make_train_function()
# -> 1088       outputs = self.train_function(ins)  # pylint: disable=not-callable
#    1089
#    1090     if reset_metrics:
#
# /opt/conda/envs/trial_env_01/lib/python3.7/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3955
#    3956     fetched = self._callable_fn(*array_vals,
# -> 3957                                 run_metadata=self.run_metadata)
#    3958     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3959     output_structure = nest.pack_sequence_as(
#
# /opt/conda/envs/trial_env_01/lib/python3.7/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1480         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1481                                                self._handle, args,
# -> 1482                                                run_metadata_ptr)
#    1483         if run_metadata:
#    1484           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# InvalidArgumentError: 2 root error(s) found.
#   (0) Invalid argument: Incompatible shapes: [192,3,32,84,5] vs. [64,1,1,1,1]
# 	 [[{{node random_weighted_average/mul_1}}]]
# 	 [[loss/Identity_1/_4559]]
#   (1) Invalid argument: Incompatible shapes: [192,3,32,84,5] vs. [64,1,1,1,1]
# 	 [[{{node random_weighted_average/mul_1}}]]
# 0 successful operations.
# 0 derived errors ignored.
